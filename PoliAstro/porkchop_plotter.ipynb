# %%
import numpy as np

import astropy.units as u
from astropy.time import Time
from astropy.coordinates import solar_system_ephemeris

from poliastro.twobody import Orbit
from poliastro.maneuver import Maneuver
from poliastro.iod import izzo
from poliastro.plotting import OrbitPlotter2D
from poliastro.util import norm



from poliastro.plotting.porkchop import porkchop
from poliastro.bodies import Earth, Mars, Venus, Saturn, Jupiter, Sun
from poliastro.util import time_range

# %%
launch_span = time_range("2020-01-30", end="2045-01-30")
arrival_span = time_range("2020-01-30", end="2056-01-30")
max_c3 = 200* (u.km/u.s)**2

dv_launch, dev_dpt, c3dpt, c3arr, tof = porkchop(Jupiter, Saturn, launch_span, arrival_span, max_c3=max_c3)
# Out:
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 46 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 47 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-95fd861b16a1> in <module>()
#       3 max_c3 = 200* (u.km/u.s)**2
#       4
# ----> 5 dv_launch, dev_dpt, c3dpt, c3arr, tof = porkchop(Jupiter, Saturn, launch_span, arrival_span, max_c3=max_c3)
# ...

# %%
sol = porkchop(Earth, Jupiter, launch_span, arrival_span, max_c3=max_c3)
# Out:
# WARNING: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# /Users/Devansh/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning:
#
# No contour levels were found within the data range.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c70cf844599a> in <module>()
# ----> 1 sol = porkchop(Earth, Jupiter, launch_span, arrival_span, max_c3=max_c3)
#
# ~/anaconda3/lib/python3.6/site-packages/poliastro/plotting/porkchop.py in porkchop(departure_body, target_body, launch_span, arrival_span, ax, tfl, vhp, max_c3, max_vhp)
#     194
#     195     return (
# ...

# %%
sol = porkchop(Venus, Earth, launch_span, arrival_span, max_c3=max_c3)
# Out:
# WARNING: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3774d5a1858c> in <module>()
# ----> 1 sol = porkchop(Venus, Earth, launch_span, arrival_span, max_c3=max_c3)
#
# ~/anaconda3/lib/python3.6/site-packages/poliastro/plotting/porkchop.py in porkchop(departure_body, target_body, launch_span, arrival_span, ax, tfl, vhp, max_c3, max_vhp)
#     194
#     195     return (
# --> 196         dv_launch * u.km / u.s,
#     197         dv_arrival * u.km / u.s,
#     198         c3_launch * u.km ** 2 / u.s ** 2,
#
# ...

# %%
sol = porkchop( Jupiter, Saturn,launch_span, arrival_span, max_c3=max_c3)
# Out:
# WARNING: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-768b4ca3755f> in <module>()
# ----> 1 sol = porkchop( Jupiter, Saturn,launch_span, arrival_span, max_c3=max_c3)
#
# ~/anaconda3/lib/python3.6/site-packages/poliastro/plotting/porkchop.py in porkchop(departure_body, target_body, launch_span, arrival_span, ax, tfl, vhp, max_c3, max_vhp)
#     194
#     195     return (
# --> 196         dv_launch * u.km / u.s,
#     197         dv_arrival * u.km / u.s,
#     198         c3_launch * u.km ** 2 / u.s ** 2,
#
# ...

# %%
sol
# Out:
# (<Quantity [[ 42.99500731, 36.07447255, 30.3161549 ,...,  25.67206422,
#               27.17357764, 28.89900368],
#             [ 50.12309518, 47.27163265, 39.95113005,...,  20.64103717,
#               21.59904838, 22.66783982],
#             [ 48.39956959, 49.59004958, 50.77225584,...,  16.93294598,
#               17.56092094, 18.247148  ],
#             ...,
#             [ 53.10561635, 54.06648616, 55.0156256 ,...,  27.90259711,
#               28.8746809 , 29.85916644],
#             [ 51.65200522, 52.6271472 , 53.59198205,...,  26.47420934,
#               27.42859421, 28.39592464],
#             [ 50.17512853, 51.16234305, 52.14068832,...,  25.07925174,
#               26.01286844, 26.96064957]] km / s>,
#  <Quantity [[ 32.69708926, 26.92359435, 22.0473979 ,...,  31.36757802,
#               33.40882097, 35.69486052],
#             [ 38.9884999 , 36.39553509, 30.33962277,...,  25.4324727 ,
#               26.87852449, 28.45469059],
# ...

# %%
sol
# Out:
# (<Quantity [[ 42.99500731, 36.07447255, 30.3161549 ,...,  25.67206422,
#               27.17357764, 28.89900368],
#             [ 50.12309518, 47.27163265, 39.95113005,...,  20.64103717,
#               21.59904838, 22.66783982],
#             [ 48.39956959, 49.59004958, 50.77225584,...,  16.93294598,
#               17.56092094, 18.247148  ],
#             ...,
#             [ 53.10561635, 54.06648616, 55.0156256 ,...,  27.90259711,
#               28.8746809 , 29.85916644],
#             [ 51.65200522, 52.6271472 , 53.59198205,...,  26.47420934,
#               27.42859421, 28.39592464],
#             [ 50.17512853, 51.16234305, 52.14068832,...,  25.07925174,
#               26.01286844, 26.96064957]] km / s>,
#  <Quantity [[ 32.69708926, 26.92359435, 22.0473979 ,...,  31.36757802,
#               33.40882097, 35.69486052],
#             [ 38.9884999 , 36.39553509, 30.33962277,...,  25.4324727 ,
#               26.87852449, 28.45469059],
# ...
